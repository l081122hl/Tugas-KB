# %% [markdown]
# <a href="https://colab.research.google.com/github/l081122hl/Tugas-KB/blob/main/TugasKB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tugas Kecerdasan Buatan

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns # Untuk membuat grafik menarik

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-698b783b-3b35-48ac-8f58-b6de3882fc0b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-698b783b-3b35-48ac-8f58-b6de3882fc0b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('winequality-red.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Untuk melihat sebaran data kualitas wine — apakah cenderung banyak wine berkualitas menengah, rendah, atau tinggi.
# Tujuan: Mengetahui distribusi nilai 'quality' (apakah seimbang atau tidak)
# Fungsi: Melihat apakah dataset memiliki banyak wine berkualitas rendah/tinggi dan bagaimana distribusinya.
# Ini penting untuk menentukan apakah model prediksi nanti perlu penanganan imbalance data.
plt.hist(df['quality'], bins=6, color='salmon', edgecolor='black')
# Out:
# (array([ 10.,  53., 681., 638., 199.,  18.]),
#  array([3.        , 3.83333333, 4.66666667, 5.5       , 6.33333333,
#         7.16666667, 8.        ]),
#  <BarContainer object of 6 artists>)

# %%
plt.title('Distribusi Kualitas Wine')
# Out:
# Text(0.5, 1.0, 'Distribusi Kualitas Wine')

# %%
plt.xlabel('Quality')
# Out:
# Text(0.5, 0, 'Quality')

# %%
plt.ylabel('Jumlah Sampel')
# Out:
# Text(0, 0.5, 'Jumlah Sampel')

# %%
plt.grid(True)

# %%
plt.show()
